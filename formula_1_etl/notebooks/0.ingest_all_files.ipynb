# %% [markdown]
# # Execute all ingestion notebooks sequentially

# %%
notebooks = [
    "02_silver/1.ingest_circuits_file",
    "02_silver/2.ingest_races_file",
    "02_silver/3.ingest_constructors_file",
    "02_silver/4.ingest_drivers_file",
    "02_silver/5.ingest_results_file",
    "02_silver/6.ingest_pit_stops_file",
    "02_silver/7.ingest_lap_times_file",
    "02_silver/8.ingest_qualifying_file"
]

for notebook in notebooks:
    print(f"Executing {notebook}...")
    result = dbutils.notebook.run(notebook, 0, {"p_data_source": "Ergast API"})
    print(f"Result: {result}")
